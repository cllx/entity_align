# %%
fang_360 = {'基本信息':{'中文名':'方滨兴','外文名':'','性别':'','出生日期':'1960年7月','出生地':'黑龙江哈尔滨市','国籍':'中国',
            '民族':'汉族','职业':'国家计算机网络应急技术处理协调中心主任','毕业院校':'哈尔滨工业大学','政治面貌':'中国共产党', 
            '代表作品':'','主要成就':'','曾任职':'','信仰':'无','原籍':''},
            '人物履历':{'教育经历':{'本科':{'起始时间':'1978','结束时间':'1981','学校名称':'哈尔滨工业大学','所属院系名':'计算机系','学历':'本科','学位':'学士学位'},
                                    '硕士研究生':{'起始时间':'1982','结束时间':'1984','学校名称':'清华大学','所属院系名':'计算机系','导师':'','学历':'研究生','学位':'硕士学位'},
                                    '博士研究生':{'起始时间':'1986','结束时间':'1989','学校名称':'哈尔滨工业大学','所属院系名':'计算机系','导师':'','学历':'在职博士研究生','学位':'博士学位'},
                                    '博士后':{'起始时间':'1990','结束时间':'1993','学校名称':'国防科学技术大学','所属院系名':'计算机科学与技术','导师':'','学历':'','学位':''}},
                        '工作经历':{'任职':[{'起始时间':'1984','结束时间':'1992','地点':'','所在单位':'哈尔滨工业大学计算机系','职称':'助教/讲师/副教授/教研室副主任'},
                                            {'起始时间':'1992','结束时间':'1995','地点':'','所在单位':'哈尔滨工业大学计算机系','职称':'教授/教研室副主任、主任'},
                                            {'起始时间':'1995','结束时间':'1999','地点':'','所在单位':'哈尔滨工业大学计算机与电气工程学院','职称':'教授/博士生导师/教研室主任，副院长，网络中心主任'},
                                            {'起始时间':'1999','结束时间':'2000','地点':'','所在单位':'国家计算机网络应急技术处理协调中心','职称':'副总工'},
                                            {'起始时间':'2000','结束时间':'2002','地点':'','所在单位':'国家计算机网络应急技术处理协调中心','职称':'总工程师/副主任/教授级高级工程师'},
                                            {'起始时间':'2002','结束时间':'2006','地点':'','所在单位':'国家计算机网络应急技术处理协调中心','职称':'主任/总工程师/教授级高级工程师'},
                                            {'起始时间':'2003','结束时间':'2007','地点':'','所在单位':'信息产业部互联网应急处理协调办公室','职称':'主任'},
                                            {'时间时间':'2003','结束时间':'2007','地点':'','所在单位':'国家计算机网络与信息安全管理中心','职称':'名誉主任'},
                                            {'起始时间':'2007年12月','结束时间':'2013年6月','地点':'','所在单位':'北京邮电大学','职称':'校长'},],
                                    '任免辞职':[{'时间点':'2013年6月','信息公布权威机关':'','任免_辞职':'北邮校长'}]}},
            '其他职务':{'学术兼职':[{'起始时间':'2003年','结束时间':'','组织机构':'中国通信标准化协会','职位_职称':'理事'},
                                    {'起始时间':'2004年','结束时间':'','组织机构':'中国互联网协会','职位_职称':'副理事长'},
                                    {'起始时间':'2004年','结束时间':'','组织机构':'网络与信息安全工作委员会','职位_职称':'主任'},
                                    {'起始时间':'2005年','结束时间':'','组织机构':'中国通信学会','职位_职称':'会士/常务理事'},
                                    {'起始时间':'2005年','结束时间':'','组织机构':'中国通信学会','职位_职称':'学术工作委员会委员'},
                                    {'起始时间':'2005年','结束时间':'','组织机构':'清华大学计算机系','职位_职称':'教授'},
                                    {'起始时间':'2007年','结束时间':'','组织机构':'中科院计算所','职位_职称':'客座研究员\博士生导师\信息安全首席科学家'},
                                    {'起始时间':'2007年','结束时间':'','组织机构':'国防科学技术大学','职位_职称':'教授/博士生导师'},
                                    {'起始时间':'2007年','结束时间':'','组织机构':'《通信学报》','职位_职称':'编辑委员会主任'},
                                    {'起始时间':'2008年','结束时间':'','组织机构':'中国计算机学会','职位_职称':'副理事长/计算机安全专业委员会主任'}],
                        '技术工作兼职':[{'起始时间':'2003年','结束时间':'','组织机构':'网络与信息安全技术委员会','职位_职称':'主席/专家咨询委员会委员/技术管理委员会委员'},
                                        {'起始时间':'2005年','结束时间':'','组织机构':'通信安全技术委员会','职位_职称':'主任'},
                                        {'起始时间':'2004年','结束时间':'','组织机构':'中国下一代互联网示范工程','职位_职称':'项目专家委员会委员'},
                                        {'起始时间':'2005年','结束时间':'','组织机构':'全国人大信息化系统改造和建设工程','职位_职称':'专家咨询顾问组成员'},
                                        {'起始时间':'2005年','结束时间':'','组织机构':'国家863计划“十一五”信息技术','职位_职称':'专家委员会委员'},
                                        {'起始时间':'2007年','结束时间':'','组织机构':'国家自然科学基金可信软件','职位_职称':'重大专项专家组副组长'},
                                        {'起始时间':'2007年','结束时间':'','组织机构':'国家973计划“信息安全理论及若干关键技术”','职位_职称':'首席科学家'},
                                        {'起始时间':'2002年','结束时间':'','组织机构':'信息产业部','职位_职称':'通信科学技术委员会常务委员'},
                                        {'起始时间':'2004年','结束时间':'','组织机构':'国家计算机网络与信息安全管理中心','职位_职称':'科学技术委员会主任'},
                                        {'起始时间':'2004年','结束时间':'','组织机构':'解放军总后勤部','职位_职称':'信息化专家咨询委员会委员'},
                                        {'起始时间':'2005年','结束时间':'','组织机构':'国家信息安全产品认证管理委员会','职位_职称':'委员'},
                                        {'起始时间':'2006年','结束时间':'','组织机构':'国家信息化专家咨询委员会','职位_职称':'委员'},
                                        {'起始时间':'2006年','结束时间':'','组织机构':'网络与信息安全专业委员会','职位_职称':'副主任'},
                                        {'起始时间':'2006年','结束时间':'','组织机构':'国家应急管理','职位_职称':'专家组成员'},
                                        {'起始时间':'2007年','结束时间':'','组织机构':'公安部','职位_职称':'信息安全特聘专家'},
                                        {'起始时间':'2007年','结束时间':'','组织机构':'“新世纪百千万人才工程国家级人选”评审委员会','职位_职称':'委员'},
                                        ],
                        '社会兼职':[{'起始时间':'2006年','结束时间':'','组织机构':'上海市互联网宣传管理','职位_职称':'技术咨询专家'},
                                    {'起始时间':'2007年','结束时间':'','组织机构':'北京市公安交通管理局','职位_职称':'专家顾问团成员'},
                                    {'起始时间':'2006年','结束时间':'','组织机构':'北京市信息化专家咨询委员会','职位_职称':'委员'},
                                    {'起始时间':'2005年','结束时间':'','组织机构':'中国网络通信集团公司','职位_职称':'技术委员会委员'},
                                    {'起始时间':'2003年','结束时间':'','组织机构':'财政部','职位_职称':'“金财工程”专家咨询委员会委员'}]},
            '科研方向':'',
            '研究领域':['计算机网络以及网络与信息安全的理论与技术','新一代互联网技术','并行处理技术','复杂巨系统理论的应用技术','计算机网络安全技术及计算机内容安全技术的研究','侧重点在于信息安全体系框架的研究','网络协议分析技术','IPv6技术','网络应急处理技术','系统灾备技术','入侵检测技术','honey-net技术','计算机病毒技术','信息捕获与分析技术','高效文字匹配算法研究','网络健壮性研究','网格计算及其安全技术'],
            '主要荣誉':[{'时间点':'2001年','颁奖单位':'国务院','授予奖项名称':'国务院政府特殊津贴'},
                        {'时间点':'2001年','颁奖单位':'中组部、中宣部、中央政法委、公安部、民政部、人事部','授予奖项名称':'“先进个人”称号'},
                        {'时间点':'2001年','颁奖单位':'信息产业部','授予奖项名称':'“在信息产业部重点工程中做出突出贡献特等奖先进个人”称号'},
                        {'时间点':'2002年','颁奖单位':'中组部中宣部、人事部、科技部','授予奖项名称':'全国“杰出专业技术人才”荣誉称号'},
                        {'时间点':'2004年','颁奖单位':'人事部、科学技术部、教育部、财政部、国家发展和改革委员会、国家自然科学基金委员会、中国科学技术协会','授予奖项名称':'“新世纪百千万人才工程国家级人选”'},
                        {'时间点':'2006年','颁奖单位':'信息产业部','授予奖项名称':'信息产业科技创新先进工作者'},
                        {'时间点':'2007年','颁奖单位':'何梁何利基金','授予奖项名称':'何梁何利基金科学与技术进步奖'}],
            '主要成果':{'学术论著类':[{'时间点':'1992年','论著名称':'《计算机病毒及其对策》'},
                                      {'时间点':'1992年','论著名称':'《计算机病毒及其对策》'},
                                      {'时间点':'2002年','论著名称':'建设网络应急体系,保障网络空间安全'}],
                        '散文类':'',
                        '承担项目类':[{'时间点':'2002年','项目名称':'信息安全管理系统'},
                                      {'时间点':'2002年','项目名称':'大范围宽带网络动态处置系统'},
                                      {'时间点':'2004年','项目名称':'大规模网络信息获取系统'},
                                      {'时间点':'2005年','项目名称':'搜索引擎安全管理系统'},
                                      {'时间点':'2007年','项目名称':'通信数据安全管理系统'}],
                        '研究成果类':[{'时间点':'2001年','研究成果名称':'计算机病毒及其预防技术'},
                                      {'时间点':'2004年','研究成果名称':'国家信息安全展略研究'},
                                      {'时间点':'1995年','研究成果名称':'支持存储器无冲突访问的互连开关门阵列芯片的研制'},
                                      {'时间点':'1995年','研究成果名称':'多机系统的性能评价的研究'},
                                      {'时间点':'2001年','研究成果名称':'计算机病毒及其预防技术'},
                                      {'时间点':'1996年','研究成果名称':'支持存储器无冲突访问的互连开关设计理论及方法'},
                                      {'时间点':'1996年','研究成果名称':'ABC-90阵列计算机综合模拟器'}],
                        '发明专利类':'',
                        '人才培养类':''},
            '学术报告':'',
            '外界评价':'',
            '人物影响':'',
            '个性寄语':'',
            '社会争议_争议事件':'',
            '获奖争议':''}

fang_baidu = {'基本信息':{'中文名':'方滨兴','外文名':'Bin xing Fang','性别':'男','出生日期':'1960年07月17日','出生地':'黑龙江省哈尔滨市','国籍':'中国',
              '民族':'汉族','职业':'科研工作者','毕业院校':'哈尔滨工业大学','政治面貌':'中国共产党党员','代表作品':'《论网络空间主权》、《在线社交网络分析》',
              '主要成就':'2005年当选为中国工程院院士','曾任职':'','信仰':'','原籍':'江西省上饶市万年县'},
              '人物履历':{'教育经历':{'本科':{'起始时间':'','结束时间':'1982年1月','学校名称':'哈尔滨工业大学','所属院系名':'','学历':'','学位':'学士学位'},
                                      '硕士研究生':{'起始时间':'1982年1月','结束时间':'1984年10月','学校名称':'清华大学','所属院系名':'计算机组织与系统结构专业','导师':'','学历':'研究生','学位':'硕士学位'},
                                      '博士研究生':{'起始时间':'1986年2月','结束时间':'1989年9月','学校名称':'哈尔滨工业大学','所属院系名':'','导师':'','学历':'在职博士研究生','学位':''},
                                      '博士后':{'起始时间':'1990年4月','结束时间':'1993年10月','学校名称':'国防科学技术大学','所属院系名':'计算机科学与技术','导师':'胡守仁','学历':'','学位':''}},
                          '工作经历':{'任职':[{'起始时间':'1984年10月','结束时间':'1992年','地点':'','所在单位':'哈尔滨工业大学计算机系','职称':'助教、讲师、副教授'},
                                              {'起始时间':'1992年','结束时间':'','地点':'','所在单位':'哈尔滨工业大学计算机系','职称':'教授'},
                                              {'起始时间':'1995年','结束时间':'','地点':'','所在单位':'哈尔滨工业大学计算机系','职称':'博士生导师'},
                                              {'起始时间':'1997年6月','结束时间':'1999年6月','地点':'','所在单位':'哈尔滨工业大学计算机与电气工程学院','职称':'副院长'},
                                              {'起始时间':'1998年8月','结束时间':'1999年6月','地点':'','所在单位':'哈尔滨工业大学网络中心','职称':'主任'},
                                              {'起始时间':'1999年7月','结束时间':'','地点':'','所在单位':'国家计算机网络应急技术处理协调中心','职称':''},
                                              {'起始时间':'1999年','结束时间':'2000年','地点':'','所在单位':'国家计算机网络应急技术处理协调中心','职称':'副总工'},
                                              {'时间时间':'2000年','结束时间':'2002年','地点':'','所在单位':'国家计算机网络应急技术处理协调中心','职称':'总工程师、副主任、教授级高级工程师'},
                                              {'起始时间':'2002年','结束时间':'2006年','地点':'','所在单位':'国家计算机网络应急技术处理协调中心','职称':'主任'},
                                              {'起始时间':'2003年4月','结束时间':'2008年1月','地点':'','所在单位':'信息产业部互联网应急处理协调办公室','职称':'主任'},
                                              {'起始时间':'2006年','结束时间':'','地点':'','所在单位':'国家计算机网络与信息安全管理中心','职称':'名誉主任'},
                                              {'起始时间':'2007年12月','结束时间':'2013年6月','地点':'','所在单位':'北京邮电大学','职称':'校长'},
                                              {'起始时间':'2016年3月25日','结束时间':'','地点':'北京','所在单位':'中国网络空间安全协会','职称':'理事长'},
                                              {'起始时间':'2017年7月','结束时间':'','地点':'','所在单位':'广州大学网络空间先进技术研究院','职称':'名誉院长'}],
                                      '任免辞职':[{'时间点':'2013年6月','信息公布权威机关':'','任免_辞职':'北邮校长'}]}},
              '其他职务':{'学术兼职':[{'起始时间':'2002年','结束时间':'','组织机构':'信息产业部通信科学技术委员会','职位_职称':'常务委员'},
                                      {'起始时间':'2003年','结束时间':'','组织机构':'中国通信标准化协会','职位_职称':'理事'},
                                      {'起始时间':'2004年','结束时间':'','组织机构':'中国互联网协会','职位_职称':'副理事长'},
                                      {'起始时间':'2004年','结束时间':'','组织机构':'网络与信息安全工作委员会','职位_职称':'主任'},
                                      {'起始时间':'2005年','结束时间':'','组织机构':'中国通信学会','职位_职称':'会士、常务理事、通信安全技术委员会主任、学术工作委员会委员'},
                                      {'起始时间':'2005年','结束时间':'','组织机构':'清华大学计算机系','职位_职称':'教授'},
                                      {'起始时间':'2006年','结束时间':'','组织机构':'哈尔滨工业大学','职位_职称':'教授、博士生导师'},
                                      {'起始时间':'2006年','结束时间':'','组织机构':'哈尔滨工业大学国家计算机内容安全重点实验室','职位_职称':'主任'},
                                      {'起始时间':'2007年','结束时间':'','组织机构':'“新世纪百千万人才工程国家级人选”评审委员会','职位_职称':'委员'},
                                      {'起始时间':'2007年','结束时间':'','组织机构':'中国科学院计算所','职位_职称':'客座研究员、博士生导师、信息安全首席科学家'},
                                      {'起始时间':'2007年','结束时间':'','组织机构':'国防科学技术大学','职位_职称':'教授、博士生导师'},
                                      {'起始时间':'2007年','结束时间':'','组织机构':'《通信学报》编辑委员会','职位_职称':'主任'},
                                      {'起始时间':'2007年','结束时间':'','组织机构':'国家自然科学基金可信软件','职位_职称':'重大专项专家组副组长'},
                                      {'起始时间':'2008年','结束时间':'','组织机构':'中国计算机学会','职位_职称':'副理事长'},
                                      {'起始时间':'2008年','结束时间':'','组织机构':'计算机安全专业委员会','职位_职称':'主任'},
                                      {'起始时间':'2016年8月','结束时间':'','组织机构':'哈尔滨工业大学（深圳）计算机学院','职位_职称':'首席学术顾问'},
                                      {'起始时间':'2016年12月','结束时间':'','组织机构':'中国云安全与新兴技术安全创新联盟','职位_职称':'理事长'},
                                      {'起始时间':'2016年12月','结束时间':'','组织机构':'教育部网络空间安全学科','职位_职称':'评议组召集人'},
                                      {'起始时间':'2016年12月','结束时间':'','组织机构':'中国中文信息学会','职位_职称':'第八届理事会理事长'}],
                          '技术工作兼职':[{'起始时间':'2003年','结束时间':'','组织机构':'网络与信息安全技术委员会','职位_职称':'主席、专家咨询委员会委员、技术管理委员会委员'},
                                          {'起始时间':'2004年','结束时间':'','组织机构':'中国下一代互联网示范工程','职位_职称':'项目专家委员会委员'},
                                          {'起始时间':'2004年','结束时间':'','组织机构':'国家计算机网络与信息安全管理中心','职位_职称':'科学技术委员会主任'},
                                          {'起始时间':'2004年','结束时间':'','组织机构':'解放军总后勤部','职位_职称':'信息化专家咨询委员会委员'},
                                          {'起始时间':'2005年','结束时间':'','组织机构':'国家信息安全产品认证委员会','职位_职称':'委员'},
                                          {'起始时间':'2005年','结束时间':'','组织机构':'中国网络通信集团公司','职位_职称':'技术委员会委员'},
                                          {'起始时间':'2005年','结束时间':'','组织机构':'全国人大信息化系统改造和建设工程','职位_职称':'专家咨询顾问组成员'},
                                          {'起始时间':'2005年','结束时间':'','组织机构':'国家863计划“十一五”信息技术领域','职位_职称':'专家委员会委员'},
                                          {'起始时间':'2006年','结束时间':'','组织机构':'国家信息化专家咨询委员会','职位_职称':'委员'},
                                          {'起始时间':'2006年','结束时间':'','组织机构':'网络与信息安全专业委员会','职位_职称':'副主任'},
                                          {'起始时间':'2006年','结束时间':'','组织机构':'国家应急管理','职位_职称':'专家组成员'},
                                          {'起始时间':'2007年','结束时间':'','组织机构':'公安部','职位_职称':'信息安全特聘专家'},
                                          {'起始时间':'2016年12月','结束时间':'','组织机构':'信息内容安全技术国家工程实验室','职位_职称':'主任'},
                                          {'起始时间':'2016年12月','结束时间':'','组织机构':'国家八六三计划信息安全主题组','职位_职称':'专家'},
                                          {'起始时间':'2016年12月','结束时间':'','组织机构':'国家发展改革委信息安全专家咨询组','职位_职称':'成员'}],
                          '社会兼职':[{'起始时间':'2003年','结束时间':'','组织机构':'财政部','职位_职称':'“金财工程”专家咨询委员会委员'},
                                      {'起始时间':'2006年','结束时间':'','组织机构':'上海市互联网宣传管理','职位_职称':'技术咨询专家'},
                                      {'起始时间':'2006年','结束时间':'','组织机构':'北京市信息化专家咨询委员会','职位_职称':'委员'},
                                      {'起始时间':'2007年','结束时间':'','组织机构':'北京市公安交通管理局','职位_职称':'专家顾问团成员'},
                                      {'起始时间':'2008年','结束时间':'2013年','组织机构':'中华人民共和国第十一届全国人民代表大会','职位_职称':'代表'},
                                      {'起始时间':'2016年12月','结束时间':'','组织机构':'中国电子信息产业集团','职位_职称':'首席科学家'}]},
              '科研方向':[{'起始时间':'20世纪90年代末','结束时间':'','方向':'计算机安全事件入侵检测','所获奖项':''},
                          {'起始时间':'1999年','结束时间':'','方向':'国家信息安全基础设施','所获奖项':''}],
              '研究领域':['网络与信息安全的理论与技术','侧重点在于信息安全体系框架的研究','网络协议分析技术','IPv6技术','网络应急处理技术','系统灾备技术','入侵检测技术','honey-net技术','计算机病毒技术','信息捕获与分析技术','高效文字匹配算法研究','网络健壮性研究','网格计算及其安全技术'],
              '主要荣誉':[{'时间点':'2001年','颁奖单位':'信息产业部','授予奖项名称':'“在信息产业部重点工程中做出突出贡献特等奖先进个人”称号'},
                          {'时间点':'2001年','颁奖单位':'中华人民共和国国务院','授予奖项名称':'国务院政府特殊津贴专家'},
                          {'时间点':'2002年','颁奖单位':'中组部、中宣部、人事部、科技部联合','授予奖项名称':'全国“杰出专业技术人才”荣誉称号'},
                          {'时间点':'2006年8月','颁奖单位':'信息产业部','授予奖项名称':'信息产业科技创新先进工作者'},
                          {'时间点':'2006年','颁奖单位':'《计算机世界》','授予奖项名称':'中国信息安全保障突出贡献奖'},
                          {'时间点':'2007年','颁奖单位':'何梁何利基金会','授予奖项名称':'何梁何利基金科学与技术进步奖'},
                          {'时间点':'2014年','颁奖单位':'人民网、新华网、中国网络电视台','授予奖项名称':'中国互联网年度人物特别贡献奖'},],
              '主要成果':{'学术论著类':[{'时间点':'1980','论著名称':'《ECLIPSE MV/8000超级小型机产品介绍》'},
                                        {'时间点':'1992年','论著名称':'《计算机病毒及其防范》'},
                                        {'时间点':'1992.09','论著名称':'《计算机病毒及其对策》'},
                                        {'时间点':'2010.12','论著名称':'《网和天下 三网融合理论、实验与信息安全》'},
                                        {'时间点':'2014.11','论著名称':'《在线社交网络分析》'},
                                        {'时间点':'2017.09','论著名称':'《论网络空间主权》'}],
                          '散文类':'',
                          '承担项目类':[{'时间点':'2007年','项目名称':'信息安全理论及若干关键技术'},
                                        {'时间点':'2010年','项目名称':'非常规突发事件中网络舆情作用机制与相关技术研究'},
                                        {'时间点':'2010年','项目名称':'Web搜索与挖掘的新理论和新方法—支持舆情监控的Web搜索与挖掘的理论与方法研究'},
                                        {'时间点':'2008年','项目名称':'网络环境下特定信息获取与处理技术国防科技创新团队项目'},
                                        {'时间点':'2009年','项目名称':'下一代互联网舆情管理系统应用示范'},
                                        {'时间点':'2006年','项目名称':'大规模网络入侵定位与容忍'}],
                          '研究成果类':[{'时间点':'1995年','研究成果名称':'支持存储器无冲突访问的互联网络开关门阵列芯片的研制'},
                                        {'时间点':'1995年','研究成果名称':'多机系统的性能评价的研究'},
                                        {'时间点':'1996年','研究成果名称':'支持存储器无冲突访问的互连开关设计理论及方法'},
                                        {'时间点':'1996年','研究成果名称':'ABC-90阵列计算机综合模拟器'},
                                        {'时间点':'2001年','研究成果名称':'计算机病毒及其预防技术'},
                                        {'时间点':'2002年','研究成果名称':'国家信息安全管理系统'},
                                        {'时间点':'2002年','研究成果名称':'大范围宽带网络动态处置系统'},
                                        {'时间点':'2004年','研究成果名称':'大规模网络信息获取系统'},
                                        {'时间点':'2004年','研究成果名称':'国家信息安全展略研究'},
                                        {'时间点':'2005年','研究成果名称':'搜索引擎安全管理系统'},
                                        {'时间点':'2007年','研究成果名称':'国家通信数据安全管理系统'},
                                        {'时间点':'2015年','研究成果名称':'在线社交网络分析关键技术及系统'},
                                        {'时间点':'2018年','研究成果名称':'大规模网络安全态势分析关键技术及系统YHSAS'}],
                          '发明专利类':'',
                          '人才培养类':[{'时间点':'','教育理念':'网络空间安全人才培养存在三个特殊性：一是自身网络安全的特殊性；二是人才特殊性；三是网络空间安全人才培养的特殊性'},
                                        {'时间点':'2017年3月','指导学生':'培养硕士与博士生百余名'}]},
              '学术报告':[{'时间点':'2014年11月19日','演讲报告题目':'《物联网搜索技术》','组织单位_活动单位名称':'世界互联网大会','地点':'','重要观点':'','全体观众':''}],
              '外界评价':'',
              '人物影响':'',
              '个性寄语':'',
              '社会争议_争议事件':'',
              '获奖争议':''}
print("  ",(fang_360))
print("\n\n  ",(fang_baidu))
# Out:
#    {'基本信息': {'中文名': '方滨兴', '外文名': '', '性别': '', '出生日期': '1960年7月', '出生地': '黑龙江哈尔滨市', '国籍': '中国', '民族': '汉族', '职业': '国家计算机网络应急技术处理协调中心主任', '毕业院校': '哈尔滨工业大学', '政治面貌': '中国共产党', '代表作品': '', '主要成就': '', '曾任职': '', '信仰': '无', '原籍': ''}, '人物履历': {'教育经历': {'本科': {'起始时间': '1978', '结束时间': '1981', '学校名称': '哈尔滨工业大学', '所属院系名': '计算机系', '学历': '本科', '学位': '学士学位'}, '硕士研究生': {'起始时间': '1982', '结束时间': '1984', '学校名称': '清华大学', '所属院系名': '计算机系', '导师': '', '学历': '研究生', '学位': '硕士学位'}, '博士研究生': {'起始时间': '1986', '结束时间': '1989', '学校名称': '哈尔滨工业大学', '所属院系名': '计算机系', '导师': '', '学历': '在职博士研究生', '学位': '博士学位'}, '博士后': {'起始时间': '1990', '结束时间': '1993', '学校名称': '国防科学技术大学', '所属院系名': '计算机科学与技术', '导师': '', '学历': '', '学位': ''}}, '工作经历': {'任职': [{'起始时间': '1984', '结束时间': '1992', '地点': '', '所在单位': '哈尔滨工业大学计算机系', '职称': '助教/讲师/副教授/教研室副主任'}, {'起始时间': '1992', '结束时间': '1995', '地点': '', '所在单位': '哈尔滨工业大学计算机系', '职称': '教授/教研室副主任、主任'}, {'起始时间': '1995', '结束时间': '1999', '地点': '', '所在单位': '哈尔滨工业大学计算机与电气工程学院', '职称': '教授/博士生导师/教研室主任，副院长，网络中心主
# ...

# %%
print("  ",list(fang_360.keys()))
key_list = list(fang_baidu.keys())
# Out:
#    ['基本信息', '人物履历', '其他职务', '科研方向', '研究领域', '主要荣誉', '主要成果', '学术报告', '外界评价', '人物影响', '个性寄语', '社会争议_争议事件', '获奖争议']

# %%
from SStack import SStack
import cpca
from cpca import drawer
from DateFormatconvert2 import DateFormatHelper2
from cilin import CilinSimilarity
from queue import Queue,LifoQueue
import collections
import json

#用于将地址信息进行对齐统一
def merge_local(fang_360, fang_baidu):
    location = set()
    if fang_360=='' and fang_baidu=='':
        return fang_360
    if fang_360!='':
        location.add(fang_360)
    if fang_baidu!='':
        location.add(fang_baidu)
    if len(location)==1:
        return list(location)[0]
    df = cpca.transform(location) #实现地址信息格式的统一
    province = set()
    city = set()
    zone = set()
    address = set()
    for i in range(len(df['省'])):
        if df['省'][i]:
            province.add(df['省'][i])
        if df['市'][i]:
            city.add(df['市'][i])
        if df['区'][i]:
            zone.add(df['区'][i])
        if df['地址'][i]:
            address.add(df['地址'][i])
    if len(province)>1 or len(city)>1 or len(zone)>1 or len(address)>1: #表示地址描述不一致，需要消歧
        return 1
    else:
        last_location = ''
        if len(province)==1:
            last_location = last_location + list(province)[0]
        if len(city)==1:
            last_location = last_location + list(city)[0]
        if len(zone)==1:
            last_location = last_location + list(zone)[0]
        if len(address)==1:
            last_location = last_location + list(address)[0]
        return last_location

# 用于将日期信息进行对齐统一
def merge_date(fang_360, fang_baidu):
    date = set()
    if fang_360!='': #时间不为空的时候才放入集合进行比较
        formal_date = DateFormatHelper2.str2date(fang_360) #将日期格式进行统一
        date.add(formal_date)
    if fang_baidu!='':
        formal_date = DateFormatHelper2.str2date(fang_baidu)
        date.add(formal_date)
    if len(date)==1: #如果日期全部一样直接对齐
        date = list(date)[0]
        return date
    else: #否则判断年月日是否一样
        year = set()
        month = set()
        day = set()
        for j in list(date):
            if j.find('-')>0:
                res = j.split('-')
                if res[0]!='0':
                    year.add(res[0])
                if res[1]!='0':
                    month.add(res[1])
                if res[2]!='0':
                    day.add(res[2])
            else:
                year.add(j)
        if len(year)>1 or len(month)>1 or len(day)>1:
            return 1 #表示日期不一致，无法对齐，需要消歧
        else:
            last_date = ''
            if len(year)==1:
                last_date = last_date + list(year)[0]
            if len(month)==1:
                last_date = last_date + '-' + list(month)[0]
            if len(day)==1:
                last_date = last_date + '-' + list(day)[0]
            return last_date #返回对齐合并后的日期

# 5个文件都是列表时的对齐
def compile_list(list_360, list_baidu):
    if list_baidu=='':
        return list_360
    year = set() #年份集合
    list_360_new = []
    list_baidu_new = []
    for dict_info1 in list_360: #依次取出360百科文件列表里的元素，对其中是时间的键值进行格式统一(只取年份)
        for key,value in dict_info1.items():
            if key=='时间点' or key=='起始时间':
                value = get_year(value)
                if value!='':
                    year.add(value) #将年份添加到集合中,对齐比较时，只看相同的起始时间的内容
                dict_info1[key] = value
            if key=='结束时间':
                value = get_year(value)
                dict_info1[key] = value
        list_360_new.append(dict_info1)
    for dict_info2 in list_baidu: #依次取出百度百科文件列表里的元素，对其中是时间的键值进行格式统一(只取年份)
        for key,value in dict_info2.items():
            if key=='时间点' or key=='起始时间':
                value = get_year(value)
                if value!='':
                    year.add(value)
                dict_info2[key] = value
            if key=='结束时间':
                value = get_year(value)
                dict_info2[key] = value
        list_baidu_new.append(dict_info2)
    return_list = [] #最终返回的字典集合
    for i in list(year):
        tmp_list1 = [] #中间过度列表，用于存放两个文件中年份相同的字典
        tmp_list2 = [] #中间过度列表，用于存放两个文件中年份相同的字典
        for dict_info1 in list_360_new:
            for key,value in dict_info1.items():
                if value == i:
                    tmp_list1.append(dict_info1)
        for dict_info2 in list_baidu_new:
            for key,value in dict_info2.items():
                if value == i:
                    tmp_list2.append(dict_info2)
        if len(tmp_list1)==0 and len(tmp_list2)!=0:
            for q in tmp_list2:
                return_list.append(q)
        elif len(tmp_list1)!=0 and len(tmp_list2)==0:
            for q in tmp_list1:
                return_list.append(q)
        else:
            keys = list(tmp_list1[0].keys())
            flag_list = [] #记录360百科文件与百度百科文件的对齐的字典部分
            for content_year_baidu in tmp_list2:
                temp_dict = {} #用于存储两个文件对齐字典的中间结果
                flag = 0
                for content_year_360 in tmp_list1:
                    createVar = locals() #动态创建全局变量
                    for tmp_key in keys:
                        #这里之所以会只看这些键的值，是因为这些键的值更具有唯一性，先看具有唯一性的键值是否一样，一样才继续进行下面其他键值的比较，不一样则认为两个字典不是需要对齐的块
                        if tmp_key!='时间点' and tmp_key!='起始时间' and tmp_key!='所在单位' and tmp_key!='信息公布权威机关' and tmp_key!='组织机构' and tmp_key!='方向' and tmp_key!='颁奖单位' and tmp_key!='演讲/报告题目' and tmp_key!='事件' and tmp_key!='语录' and tmp_key!='争议起因' and tmp_key!='事件起因' and tmp_key!='教育理念/指导学生' and tmp_key!='专利名称' and tmp_key!='研究成果名称' and tmp_key!='项目名称' and tmp_key!='散文名称' and tmp_key!='论著名称':
                            createVar['tmp_360_'+tmp_key] = content_year_360[tmp_key] #分别保存两个文件该键值对应的值
                            createVar['tmp_baidu_'+tmp_key] = content_year_baidu[tmp_key]
                        if tmp_key=='所在单位' or tmp_key=='信息公布权威机关' or tmp_key=='组织机构' or tmp_key=='方向' or tmp_key=='颁奖单位' or tmp_key=='演讲/报告题目' or tmp_key=='事件' or tmp_key=='语录' or tmp_key=='争议起因' or tmp_key=='事件起因' or tmp_key=='教育理念/指导学生' or tmp_key=='专利名称' or tmp_key=='研究成果名称' or tmp_key=='项目名称' or tmp_key=='散文名称' or tmp_key=='论著名称':
                            if content_year_360[tmp_key] == content_year_baidu[tmp_key]:
                                flag = 1 #做一个关键信息相等时的标记
                                flag_list.append(content_year_360)
                            else:
                                continue #调用其他方法来对这个信息验证对齐，如果是对齐的则flag=1，如果不是则求并集保留
                    if flag==1:
                        for tmp_key in keys:
                            if tmp_key=='时间点' or tmp_key=='起始时间':
                                temp_dict[tmp_key] = i
                            elif tmp_key=='所在单位' or tmp_key=='信息公布权威机关' or tmp_key=='组织机构' or tmp_key=='方向' or tmp_key=='颁奖单位' or tmp_key=='演讲/报告题目' or tmp_key=='事件' or tmp_key=='语录' or tmp_key=='争议起因' or tmp_key=='事件起因' or tmp_key=='教育理念/指导学生' or tmp_key=='专利名称' or tmp_key=='研究成果名称' or tmp_key=='项目名称' or tmp_key=='散文名称' or tmp_key=='论著名称':
                                temp_dict[tmp_key] = content_year_360[tmp_key]
                            else:
                                if tmp_key=='结束时间':
                                    if eval('tmp_360_'+tmp_key)==eval('tmp_baidu_'+tmp_key):
                                        temp_dict[tmp_key] = content_year_360[tmp_key]
                                    else:
                                        if eval('tmp_360_'+tmp_key)!='' and eval('tmp_baidu_'+tmp_key)=='':
                                            temp_dict[tmp_key] = content_year_360[tmp_key]
                                        elif eval('tmp_360_'+tmp_key)=='' and eval('tmp_baidu_'+tmp_key)!='':
                                            temp_dict[tmp_key] = content_year_baidu[tmp_key]
                                        else:
                                            temp_dict[tmp_key] = ''
                                            pass #由消歧处理(都存在结束时间，但值不一样)
                                elif tmp_key=='地点':
                                    res = merge_local(eval('tmp_360_'+tmp_key), eval('tmp_baidu_'+tmp_key))
                                    if res==1:
                                        temp_dict[tmp_key] = ''
                                        pass #未对齐，需要消歧
                                    else:
                                        temp_dict[tmp_key] = res
                                else:
                                    if eval('tmp_360_'+tmp_key) != eval('tmp_baidu_'+tmp_key):
                                        cs = CilinSimilarity()
                                        sim = cs.similarity(eval('tmp_360_'+tmp_key), eval('tmp_baidu_'+tmp_key))
                                        if sim == 1:
                                            temp_dict[tmp_key] = eval('tmp_baidu_'+tmp_key) #相似性得分1，即存在于词库中，直接返回
                                        else:
                                            temp_dict[tmp_key] = '' #暂时未对齐，先为空
                                            pass #通过百科或其他方式实现对齐
                                    else:
                                        temp_dict[tmp_key] = eval('tmp_360_'+tmp_key)
                        break
                if flag==0:
                    return_list.append(content_year_baidu)
                else:
                    return_list.append(temp_dict)
            for content_year_360 in tmp_list1: #找出360百科文件中未与百度百科对齐的部分
                flag = 0
                for align_content_360 in flag_list:
                    for tmp_key in keys:
                        if tmp_key=='所在单位' or tmp_key=='信息公布权威机关' or tmp_key=='组织机构' or tmp_key=='方向' or tmp_key=='颁奖单位' or tmp_key=='演讲/报告题目' or tmp_key=='事件' or tmp_key=='语录' or tmp_key=='争议起因' or tmp_key=='事件起因' or tmp_key=='教育理念/指导学生' or tmp_key=='专利名称' or tmp_key=='研究成果名称' or tmp_key=='项目名称' or tmp_key=='散文名称' or tmp_key=='论著名称':
                            if content_year_360[tmp_key] == align_content_360[tmp_key]:
                                flag = 1 #做一个关键信息相等时的标记
                if flag==0:
                    return_list.append(content_year_360)
    return return_list

# 将结果写入到新json文件中
def list_to_newjson(word, res):
    if word=='本科' or word=='硕士研究生' or word=='博士研究生' or word=='博士后':
        align_json['人物履历']['教育经历'][word]=res
    elif word=='任职' or word=='任免/辞职':
        align_json['人物履历']['工作经历'][word]=res
    elif word=='学术兼职' or word=='技术工作兼职' or word=='社会兼职':
        align_json['其他职务'][word]=res
    elif word=='学术论著类' or word=='散文类' or word=='承担项目类' or word=='研究成果类' or word=='发明专利类' or word=='人才培养类':
        align_json["主要成果"][word]=res
    else:
        align_json[word]=res

# 只取日期前面的年份
def get_year(date):
    if date!='':
        date = date.strip()
        year = date[:4]
        year = year + '年'
        return year
    return date

# 维护一个键的队列
def preserve_key_queue(key, key_queue):
    if key=='任免辞职':
        delete = key_queue.get()
        delete = key_queue.get()
    elif key=='社会兼职' or key=='人才培养类' or key=='博士后':
        delete = key_queue.get()
    else:
        pass

# 对非列表且是字典形式的内容进行对齐(这里主要关注基本信息、本科、硕士、博士、博士后这几个模块)
def align_dict(content_360, content_baidu):
    keys = list(content_360.keys())
    new_dict = {} #用于存放对齐后的内容
    none_dict = [] #用于存放未对齐的内容
    for index in keys:
        if index=='起始时间' or index=='结束时间' or index=='出生日期':
            res = merge_date(content_360[index], content_baidu[index])
            if res!=1:
                new_dict[index] = res
            else:
                new_dict[index] = '' #未对齐，先暂时为空
        elif index=='出生地' or index=='原籍':
            res = merge_local(content_360[index], content_baidu[index])
            if res!=1:
                new_dict[index] = res
            else:
                new_dict[index] = '' #未对齐，先暂时为空
        else:
            if content_360[index] == content_baidu[index]:
                new_dict[index] = content_baidu[index]
            elif content_360[index]=='' and content_baidu[index]!='':
                new_dict[index] = content_baidu[index]
            elif content_360[index]!='' and content_baidu[index]=='':
                new_dict[index] = content_360[index]
            else:
                cs = CilinSimilarity()
                sim = cs.similarity(content_360[index], content_baidu[index])
                if sim == 1:
                    new_dict[index] = content_360[index] #相似性得分1，即存在于词库中
                else:
                    new_dict[index] = '' #暂时未对齐，先为空
                    pass #通过百科或其他方式实现对齐
    return new_dict
                                                        
# 对非列表字典形式的内容对齐(也包括都是列表，但列表里面都是字符串，不是字典的情况)
def string_align(word, content_360, content_baidu):
    new_list = []
    baidu_align = [] #保存百度与360对齐部分
    if word == '人物影响' or word == '研究领域': #要么为空，要么字符串值在List里
        if content_360!='' and content_baidu=='':
            new_list = content_360
        elif content_360=='' and content_baidu!='':
            new_list = content_baidu
        elif content_360!='' and content_baidu!='':
            for i in content_360:
                flag = 0
                for j in content_baidu:
                    if i==j:
                        new_list.append(i)
                        baidu_align.append(j)
                        flag=1
                        break
                    else:
                        cs = CilinSimilarity()
                        sim = cs.similarity(i, j)
                        if sim == 1:
                            new_list.append(i)
                            baidu_align.append(j)
                            flag=1
                            break
                if flag==0:
                    new_list.append(i)
            for i in content_baidu:
                flag=0
                for j in baidu_align:
                    if i==j:
                        flag=1
                if flag==0:
                    new_list.append(i)
        else:
            new_list = ''
    else: #既然content_360能够传到这里来进行计算，说明content_360此时既不是列表也不是字典，所以只能为空(如果有值的话，值的形式要么为字典，要么为列表)
        if content_baidu=='':
            new_list = content_baidu
        else:
            new_list = content_baidu
            #当有多个文件的时候，可能存在多个文件都是列表的情况，此时就又到了列表的比较函数模块了
    return new_list

# 其他信息对齐
def other_align(st, key_queue):
    if not st.is_empty():
        content = set()
        word = st.pop()
        key_queue.put(word) #键值队列，用于保存前面已出现的键值(目的是方便后面迭代时能准确找到进行到什么地方了)
        key_str = 'fang_360'
        for i in key_queue.queue: #通过维护的键的队列取到对应的键值
            key_str = key_str+'[\''+i+'\']'
        content_360 = eval(key_str) #这里可能存在里面的内容仍然是list或dict的情况
        key_str = 'fang_baidu'
        for i in key_queue.queue:
            key_str = key_str+'[\''+i+'\']'
        content_baidu = eval(key_str)
        if type(content_360).__name__ == 'list': #如果是列表，则取出列表里的每一个字典
            if word=='人物影响' or word=='研究领域':
                res = string_align(word, content_360, content_baidu)
                list_to_newjson(word, res)
                key = key_queue.get()
                preserve_key_queue(key, key_queue)
                other_align(st, key_queue)
            else:
                res = compile_list(content_360, content_baidu) #返回的是一个列表，列表里面是多个字典
                list_to_newjson(word,res)
                key = key_queue.get()
                preserve_key_queue(key, key_queue) #得到动态维护的键的队列
                other_align(st, key_queue)
        elif type(content_360).__name__ == 'dict':
            if word=='基本信息' or word=='本科' or word=='硕士研究生' or word=='博士研究生' or word=='博士后':
                res = align_dict(content_360, content_baidu)
                list_to_newjson(word,res)
                key = key_queue.get()
                preserve_key_queue(key, key_queue)
                other_align(st, key_queue)
            else:
                dict_key1 = list(content_360.keys()) #将字典里的键都放入栈中，稍后依次取出进行对齐
                dict_key1.reverse()
                for i in dict_key1:
                    st.push(i)
                other_align(st, key_queue)
        else:
            res = string_align(word, content_360, content_baidu)
            list_to_newjson(word, res)
            key = key_queue.get()
            preserve_key_queue(key, key_queue)
            other_align(st, key_queue)
    else:
        return 0

tree=lambda:collections.defaultdict(tree)
align_json=tree()
# align_json = dict() #所有对齐的结果放到最后的一个对齐字典中
st = SStack() #用栈存放每一轮的属性
lq = LifoQueue(maxsize=0) #用后进先出队列用于存放文件操作过程中的中间键值(用于新建新的对齐json)
key_list.reverse()
for i in key_list:
    st.push(i)
res = other_align(st, lq)
print("  ",json.dumps(align_json,ensure_ascii=False))
# Out:
# e:\anaconda3\lib\re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
# ...
